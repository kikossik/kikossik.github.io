# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import glob
import pathlib
from re import search

# %% [markdown]
# ### Main idea:
# look at the oil spillage data, average temperature in that state where it was spilled at that time, and the magnitude of the damage caused by specific storm events to potentially find interesting patterns and relationships between all of this dataset.

# %% [markdown]
# ## Step 1: Oil & Gas Spill Dataset

# %% [markdown]
# ### Loading and filtering datasets
# For this project I decided to analyze Oil & Gas spill dataset in the US (from Federal Pipeline and Hazardous Materials Safety Administration (PHMSA)).

# %% [markdown]
# I am loading 3 Excel files, which are in total combining all of the Oil & Gas spill data from 1986 to 2022. I am filtering this big data with so many columns to only show the ones that I am interested in analyzing.

# %% [markdown]
# **df1** = data from 1986 to 2001 |
# **df2** = data from 2002 to 2009 |
# **df3** = data from 2010 to 2022 |

# %% [markdown]
# #### Working with df1 and df2

# %%
path = "C:/Users/mobis/Desktop/lab3/Python data transformation/"

df1 = pd.read_excel(path+"oil data/hl1986to2001.xlsx")

filter_df1 = df1[["IDATE","ACSTATE","SIGNIFICANT","SERIOUS","NAME","OFFSHORE",
        "COMM","TFAT","TINJ","TOTAL_COST_CURRENT","LOSS","RECOV"]]

# %% [markdown]
# Changing date to display only year

# %%
filter_df1["IDATE"] = filter_df1["IDATE"].apply(str)
filter_df1['IDATE'] = filter_df1['IDATE'].str[:4]
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\4226254884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df1["IDATE"] = filter_df1["IDATE"].apply(str)
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\4226254884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df1['IDATE'] = filter_df1['IDATE'].str[:4]

# %%
filter_df1.isna().sum()
# Out:
# IDATE                  0
# ACSTATE               49
# SIGNIFICANT            0
# SERIOUS                0
# NAME                   0
# OFFSHORE               0
# COMM                   7
# TFAT                   1
# TINJ                   1
# TOTAL_COST_CURRENT     0
# LOSS                   9
# RECOV                 17
# dtype: int64

# %% [markdown]
# Dropping NA values

# %%
filter_df1 = filter_df1.dropna()

# %%
filter_df1.head(4)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS                  NAME OFFSHORE  \
# 0  1986      CO         YES      NO     WYCO PIPE LINE CO       NO
# 1  1986      TX         YES      NO  SEMINOLE PIPELINE CO       NO
# 2  1986      TX         YES      NO     MOBIL PIPELINE CO       NO
# 3  1986      TX         YES      NO     MOBIL PIPELINE CO       NO
#
#                  COMM  TFAT  TINJ  TOTAL_COST_CURRENT    LOSS  RECOV
# 0            GASOLINE   0.0   0.0       119875.022446  1175.0    4.0
# 1  NATURAL GAS LIQUID   0.0   0.0         3154.605854    50.0    0.0
# 2           CRUDE OIL   0.0   0.0            0.000000   400.0  350.0
# 3            GASOLINE   0.0   0.0            0.000000   164.0   87.0

# %%
df2 = pd.read_excel(path+"oil data/hl2002to2009.xlsx")

filter_df2 = df2[["IDATE","ACSTATE","SIGNIFICANT","SERIOUS","NAME","OFFSHORE",
        "COMM","FATAL","INJURE","TOTAL_COST_CURRENT",
        "SPUNIT_TEXT","LOSS","RECOV","SPILLED"]]

# %% [markdown]
# Changing date to display only year

# %%
filter_df2["IDATE"] = filter_df2["IDATE"].apply(str)
filter_df2['IDATE'] = filter_df2['IDATE'].str[:4]
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\2272135242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df2["IDATE"] = filter_df2["IDATE"].apply(str)
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\2272135242.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df2['IDATE'] = filter_df2['IDATE'].str[:4]

# %%
filter_df2.isna().sum()
# Out:
# IDATE                  0
# ACSTATE               63
# SIGNIFICANT            0
# SERIOUS                0
# NAME                   0
# OFFSHORE              11
# COMM                  47
# FATAL                  0
# INJURE                 0
# TOTAL_COST_CURRENT     0
# SPUNIT_TEXT           42
# LOSS                   0
# RECOV                  0
# SPILLED                0
# dtype: int64

# %% [markdown]
# Dropping NA values

# %%
filter_df2 = filter_df2.dropna()

# %%
filter_df2.head(4)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS                          NAME OFFSHORE  \
# 0  2002      AR          NO      NO  TE PRODUCTS PIPELINE CO., LP       NO
# 1  2002      TX         YES      NO      EQUISTAR CHEMICALS, L.P.       NO
# 2  2002      TX          NO      NO             MOBIL PIPELINE CO       NO
# 3  2002      CA          NO      NO           CHEVRON PIPELINE CO       NO
#
#                               COMM  FATAL  INJURE  TOTAL_COST_CURRENT  \
# 0                         GASOLINE      0       0          736.331361
# 1  HYDRODESULFURIZED LIGHT NAPHTHA      0       0       141840.520710
# 2                        CRUDE OIL      0       0        68825.325444
# 3                        CRUDE OIL      0       0         4331.360947
#
#   SPUNIT_TEXT  LOSS  RECOV SPILLED
# 0     GALLONS    50     45     YES
# 1     GALLONS    20      0     YES
# 2     BARRELS    10      9     YES
# 3     BARRELS     2      2     YES

# %% [markdown]
# In **df2**, some of the column names differ from **df1**, but they are identical in terms of their values. That is why some of the names in **filter_df2** are different from **filter_df1**. I will change it to the same name later on. Additionally, I added to **filter_df2** new columns _"SPUNIT_TEXT"_ and _"SPILLED"_, which are not documented for the older dataset **df1**.

# %% [markdown]
# #### Fixing df2

# %% [markdown]
# _"SPUNIT_TEXT"_ column in **filter_df2** is the _Spill Unit_ measured in either Gallons or Barrels. Since **filter_df1** only shows the data in Barrels, I am converting here all Gallons values to Barrels (1 Gallon = 0.0238095 Barrel).

# %%
filter_df2["LOSS"] = np.where(filter_df2["SPUNIT_TEXT"] == "GALLONS",
                                           filter_df2["LOSS"] * 0.0238095,
                                           filter_df2["LOSS"])
filter_df2["RECOV"] = np.where(filter_df2["SPUNIT_TEXT"] == "GALLONS",
                                           filter_df2["RECOV"] * 0.0238095,
                                           filter_df2["RECOV"])

# %% [markdown]
# Now, I will only take the _"SPILLED"_ = _YES_ values from here (since I am interested in only spill data). I didn't do this for **df1** because that older dataset didn't have this attribute.

# %%
filter_df2 = filter_df2[filter_df2["SPILLED"] == "YES"]

# %% [markdown]
# Now we can remove _"SPUNIT_TEXT"_ and _"SPILLED"_ columns.

# %%
filter_df2 = filter_df2.drop(["SPILLED","SPUNIT_TEXT"], axis=1)

# %% [markdown]
# Visual summary of the two dataframes:

# %%
filter_df1.head(1)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS               NAME OFFSHORE      COMM  \
# 0  1986      CO         YES      NO  WYCO PIPE LINE CO       NO  GASOLINE
#
#    TFAT  TINJ  TOTAL_COST_CURRENT    LOSS  RECOV
# 0   0.0   0.0       119875.022446  1175.0    4.0

# %%
filter_df2.head(1)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS                          NAME OFFSHORE  \
# 0  2002      AR          NO      NO  TE PRODUCTS PIPELINE CO., LP       NO
#
#        COMM  FATAL  INJURE  TOTAL_COST_CURRENT      LOSS     RECOV
# 0  GASOLINE      0       0          736.331361  1.190475  1.071427

# %% [markdown]
# Finally, we can rename the different columns to fit the ones for **filter_df1** (since they store exact same attributes, but some columns just have different names).

# %%
filter_df2.rename(columns={"FATAL": "TFAT", 
                   "INJURE": "TINJ"}, inplace=True)

# %%
filter_df2.head(4)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS                          NAME OFFSHORE  \
# 0  2002      AR          NO      NO  TE PRODUCTS PIPELINE CO., LP       NO
# 1  2002      TX         YES      NO      EQUISTAR CHEMICALS, L.P.       NO
# 2  2002      TX          NO      NO             MOBIL PIPELINE CO       NO
# 3  2002      CA          NO      NO           CHEVRON PIPELINE CO       NO
#
#                               COMM  TFAT  TINJ  TOTAL_COST_CURRENT       LOSS  \
# 0                         GASOLINE     0     0          736.331361   1.190475
# 1  HYDRODESULFURIZED LIGHT NAPHTHA     0     0       141840.520710   0.476190
# 2                        CRUDE OIL     0     0        68825.325444  10.000000
# 3                        CRUDE OIL     0     0         4331.360947   2.000000
#
#       RECOV
# 0  1.071427
# 1  0.000000
# 2  9.000000
# 3  2.000000

# %% [markdown]
# #### Adding df3

# %% [markdown]
# This data doesn't need any conversion, everything is expressed in Barrels.
# This dataset is the newest (data from 2010 to 2022), and the main difference between this one and the previous ones is that the _"LOSS"_ column is divided into _"UNINTENTIONAL_RELEASE_BBLS"_ (unintentional loss in barrels) and _"INTENTIONAL_RELEASE_BBLS"_ (intentional loss in barrels). Also, this data doesn't have _"SPILLED"_ column.

# %% [markdown]
# So I can combine both intentional and unintentional loss columns to get aggregate _"LOSS"_ column.

# %%
df3 = pd.read_excel(path+"oil data/hl2010toPresent.xlsx")

filter_df3 = df3[["IYEAR","OPERATOR_STATE_ABBREVIATION","SIGNIFICANT",
        "SERIOUS","NAME","ON_OFF_SHORE","COMMODITY_RELEASED_TYPE","FATAL",
        "INJURE","TOTAL_COST_CURRENT","UNINTENTIONAL_RELEASE_BBLS",
        "INTENTIONAL_RELEASE_BBLS","RECOVERED_BBLS"]]

# %% [markdown]
# Changing Year column to str to stay consistent with other dataframes

# %%
filter_df3["IYEAR"] = filter_df3["IYEAR"].apply(str)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\2456555263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df3["IYEAR"] = filter_df3["IYEAR"].apply(str)

# %%
filter_df3.isna().sum()
# Out:
# IYEAR                             0
# OPERATOR_STATE_ABBREVIATION      10
# SIGNIFICANT                       0
# SERIOUS                           0
# NAME                              0
# ON_OFF_SHORE                      0
# COMMODITY_RELEASED_TYPE           0
# FATAL                             0
# INJURE                            0
# TOTAL_COST_CURRENT                0
# UNINTENTIONAL_RELEASE_BBLS        0
# INTENTIONAL_RELEASE_BBLS       3287
# RECOVERED_BBLS                    0
# dtype: int64

# %%
filter_df3.shape
# Out:
# (4883, 13)

# %% [markdown]
# Here we can see big part of data in _"INTENTIONAL_RELEASE_BBLS"_ is full of **NA** values. Discarding every data item with **NA** value won't be smart, so instead I will **assign 0 to every NA value** and continue my calculations like that.

# %%
filter_df3["INTENTIONAL_RELEASE_BBLS"] = filter_df3["INTENTIONAL_RELEASE_BBLS"].fillna(0)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\2721907986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df3["INTENTIONAL_RELEASE_BBLS"] = filter_df3["INTENTIONAL_RELEASE_BBLS"].fillna(0)

# %% [markdown]
# Now we can remove other **NA** values (10 NA values from State column)

# %%
filter_df3 = filter_df3.dropna()

# %% [markdown]
# Now let's combine the _LOSS_ columns into one, and drop the individual ones after.

# %%
filter_df3["LOSS"] = filter_df3["UNINTENTIONAL_RELEASE_BBLS"]+filter_df3[
                                "INTENTIONAL_RELEASE_BBLS"]
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_19244\4156687068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df3["LOSS"] = filter_df3["UNINTENTIONAL_RELEASE_BBLS"]+filter_df3[

# %%
filter_df3 = filter_df3.drop(["UNINTENTIONAL_RELEASE_BBLS",
                              "INTENTIONAL_RELEASE_BBLS"], axis=1)

# %% [markdown]
# Visual summary of **filter_df1** and **filter_df3**:

# %%
filter_df1.head(1)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS               NAME OFFSHORE      COMM  \
# 0  1986      CO         YES      NO  WYCO PIPE LINE CO       NO  GASOLINE
#
#    TFAT  TINJ  TOTAL_COST_CURRENT    LOSS  RECOV
# 0   0.0   0.0       119875.022446  1175.0    4.0

# %%
filter_df3.head(1)
# Out:
#   IYEAR OPERATOR_STATE_ABBREVIATION SIGNIFICANT SERIOUS  \
# 0  2010                          OK          NO      NO
#
#                             NAME ON_OFF_SHORE  \
# 0  MAGELLAN PIPELINE COMPANY, LP      ONSHORE
#
#                              COMMODITY_RELEASED_TYPE  FATAL  INJURE  \
# 0  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...      0       0
#
#    TOTAL_COST_CURRENT  RECOVERED_BBLS  LOSS
# 0        37143.180212            0.12  0.12

# %% [markdown]
# Let's rename the columns in **filter_df3** to match with the first df.

# %%
filter_df3.rename(columns={"IYEAR": "IDATE",
                   "OPERATOR_STATE_ABBREVIATION": "ACSTATE",
                   "ON_OFF_SHORE": "OFFSHORE",
                   "COMMODITY_RELEASED_TYPE": "COMM",
                   "FATAL": "TFAT",
                   "INJURE": "TINJ",
                   "RECOVERED_BBLS": "RECOV"}, inplace=True)

# %%
# Changing order of LOSS and RECOVER
cols = list(filter_df3)
cols[11], cols[10] = cols[10], cols[11]

filter_df3 = filter_df3.loc[:,cols]

# %%
filter_df3.head(4)
# Out:
#   IDATE ACSTATE SIGNIFICANT SERIOUS                           NAME OFFSHORE  \
# 0  2010      OK          NO      NO  MAGELLAN PIPELINE COMPANY, LP  ONSHORE
# 1  2010      OK          NO      NO          CHAPARRAL ENERGY, LLC  ONSHORE
# 2  2010      TX         YES      NO       LDH ENERGY PIPELINE L.P.  ONSHORE
# 3  2010      PA          NO      NO           BUCKEYE PARTNERS, LP  ONSHORE
#
#                                                 COMM  TFAT  TINJ  \
# 0  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...     0     0
# 1                               CO2 (CARBON DIOXIDE)     0     0
# 2  HVL OR OTHER FLAMMABLE OR TOXIC FLUID WHICH IS...     0     0
# 3  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...     0     0
#
#    TOTAL_COST_CURRENT    LOSS  RECOV
# 0        37143.180212    0.12   0.12
# 1         4272.409063    2.99   0.00
# 2        32694.275618  117.00   0.00
# 3        20814.300561    0.95   0.95

# %% [markdown]
# ### Concatenating all 3 dataframes together

# %% [markdown]
# Now we can finally add all of the dataframes together.

# %%
spills_df = pd.concat([filter_df1, filter_df2, filter_df3])

# %% [markdown]
# Let's change state abbreviations to full state names.

# %%
spills_df["ACSTATE"] = spills_df["ACSTATE"].replace({"AL":"Alabama",
    "AK":"Alaska","AZ":"Arizona","AR":"Arkansas","AS":"American Samoa",
    "CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware",
    "DC":"District of Columbia","FL":"Florida","GA":"Georgia",
    "GU":"Guam","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana",
    "IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana",
    "ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan",
    "MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana",
    "NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey",
    "NM":"New Mexico","NY":"New York","NC":"North Carolina",
    "ND":"North Dakota","CM":"Northern Mariana Islands","OH":"Ohio",
    "OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","PR":"Puerto Rico",
    "RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota",
    "TN":"Tennessee","TX":"Texas","TT":"Trust Territories","UT":"Utah",
    "VT":"Vermont","VA":"Virginia","VI":"Virgin Islands","WA":"Washington",
    "WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"})

# %%
spills_df
# Out:
#      IDATE   ACSTATE SIGNIFICANT SERIOUS                                 NAME  \
# 0     1986  Colorado         YES      NO                    WYCO PIPE LINE CO
# 1     1986     Texas         YES      NO                 SEMINOLE PIPELINE CO
# 2     1986     Texas         YES      NO                    MOBIL PIPELINE CO
# 3     1986     Texas         YES      NO                    MOBIL PIPELINE CO
# 4     1986     Texas         YES      NO                 SHELL PIPE LINE CORP
# ...    ...       ...         ...     ...                                  ...
# 4878  2022     Texas         YES      NO  KINDER MORGAN LIQUID TERMINALS, LLC
# 4879  2022     Texas          NO      NO            HARVEST MIDSTREAM COMPANY
# 4880  2022     Texas         YES      NO    ENTERPRISE PRODUCTS OPERATING LLC
# 4881  2022     Texas          NO      NO       WESTERN MIDSTREAM PARTNERS, LP
# 4882  2022     Texas         YES      NO       WESTERN MIDSTREAM PARTNERS, LP
#
#      OFFSHORE                                               COMM  TFAT  TINJ  \
# 0          NO                                           GASOLINE   0.0   0.0
# 1          NO                                 NATURAL GAS LIQUID   0.0   0.0
# 2          NO                                          CRUDE OIL   0.0   0.0
# 3          NO                                           GASOLINE   0.0   0.0
# 4          NO                                          CRUDE OIL   0.0   0.0
# ...       ...                                                ...   ...   ...
# 4878  ONSHORE  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 4879  ONSHORE                                          CRUDE OIL   0.0   0.0
# 4880  ONSHORE  HVL OR OTHER FLAMMABLE OR TOXIC FLUID WHICH IS...   0.0   0.0
# 4881  ONSHORE                                          CRUDE OIL   0.0   0.0
# 4882  ONSHORE                                          CRUDE OIL   0.0   0.0
#
#       TOTAL_COST_CURRENT     LOSS   RECOV
# 0          119875.022446  1175.00    4.00
# 1            3154.605854    50.00    0.00
# 2               0.000000   400.00  350.00
# 3               0.000000   164.00   87.00
# 4               0.000000   200.00  150.00
# ...                  ...      ...     ...
# 4878       155207.525946     2.38    2.38
# 4879        17881.679277     0.48    0.48
# 4880          686.173418    23.00    0.00
# 4881        98661.935052     5.00    0.00
# 4882       301668.301306   255.39   22.00
#
# [10738 rows x 12 columns]

# %% [markdown]
# ## Step 2: Merge this data with Temperature data

# %% [markdown]
# ### Merge with Temperature per State data

# %% [markdown]
# I got the temperature data from **NOAA.gov** website.
# Going to merge the Data with my **spilled_df** dataframe.

# %%
dfs = {f.stem: pd.read_csv(f) for f in pathlib.Path().glob("states_temp_1986-2021/*.csv")}

# %%
for i in dfs:
    dfs[i]["ACSTATE"] = i

# %%
new_df = []
for i in dfs:
    new_df.append(dfs[i])

# %% [markdown]
# Some data manipulation here for the merge.

# %%
df_concat = pd.concat(new_df, ignore_index=True)
df_concat.rename(columns={"Date": "IDATE"}, inplace=True)
df_concat["IDATE"] = df_concat["IDATE"].apply(str)

# %% [markdown]
# And now the merge here:

# %%
spills_df = spills_df.merge(df_concat,how='left',left_on=['IDATE','ACSTATE'],right_on=['IDATE','ACSTATE'])

# %%
spills_df
# Out:
#       IDATE   ACSTATE SIGNIFICANT SERIOUS  \
# 0      1986  Colorado         YES      NO
# 1      1986     Texas         YES      NO
# 2      1986     Texas         YES      NO
# 3      1986     Texas         YES      NO
# 4      1986     Texas         YES      NO
# ...     ...       ...         ...     ...
# 10733  2022     Texas         YES      NO
# 10734  2022     Texas          NO      NO
# 10735  2022     Texas         YES      NO
# 10736  2022     Texas          NO      NO
# 10737  2022     Texas         YES      NO
#
#                                       NAME OFFSHORE  \
# 0                        WYCO PIPE LINE CO       NO
# 1                     SEMINOLE PIPELINE CO       NO
# 2                        MOBIL PIPELINE CO       NO
# 3                        MOBIL PIPELINE CO       NO
# 4                     SHELL PIPE LINE CORP       NO
# ...                                    ...      ...
# 10733  KINDER MORGAN LIQUID TERMINALS, LLC  ONSHORE
# 10734            HARVEST MIDSTREAM COMPANY  ONSHORE
# 10735    ENTERPRISE PRODUCTS OPERATING LLC  ONSHORE
# 10736       WESTERN MIDSTREAM PARTNERS, LP  ONSHORE
# 10737       WESTERN MIDSTREAM PARTNERS, LP  ONSHORE
#
#                                                     COMM  TFAT  TINJ  \
# 0                                               GASOLINE   0.0   0.0
# 1                                     NATURAL GAS LIQUID   0.0   0.0
# 2                                              CRUDE OIL   0.0   0.0
# 3                                               GASOLINE   0.0   0.0
# 4                                              CRUDE OIL   0.0   0.0
# ...                                                  ...   ...   ...
# 10733  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 10734                                          CRUDE OIL   0.0   0.0
# 10735  HVL OR OTHER FLAMMABLE OR TOXIC FLUID WHICH IS...   0.0   0.0
# 10736                                          CRUDE OIL   0.0   0.0
# 10737                                          CRUDE OIL   0.0   0.0
#
#        TOTAL_COST_CURRENT     LOSS   RECOV  Value
# 0           119875.022446  1175.00    4.00   46.3
# 1             3154.605854    50.00    0.00   65.5
# 2                0.000000   400.00  350.00   65.5
# 3                0.000000   164.00   87.00   65.5
# 4                0.000000   200.00  150.00   65.5
# ...                   ...      ...     ...    ...
# 10733       155207.525946     2.38    2.38    NaN
# 10734        17881.679277     0.48    0.48    NaN
# 10735          686.173418    23.00    0.00    NaN
# 10736        98661.935052     5.00    0.00    NaN
# 10737       301668.301306   255.39   22.00    NaN
#
# [10738 rows x 13 columns]

# %% [markdown]
# Since the **NOAA.gov** Data doesn't have the temperature information for each state for the year of 2022, I believe we can completely remove 2022 spillage data from our df.

# %%
spills_df = spills_df[spills_df.IDATE != "2022"]

# %%
spills_df.tail(4)
# Out:
#       IDATE     ACSTATE SIGNIFICANT SERIOUS                      NAME  \
# 10528  2021  New Jersey         YES      NO       COLLINS PIPELINE CO
# 10529  2021       Texas          NO      NO  MID - VALLEY PIPELINE CO
# 10549  2021       Texas          NO      NO           TORRENT OIL LLC
# 10722  2021       Texas          NO      NO           TORRENT OIL LLC
#
#        OFFSHORE                                               COMM  TFAT  \
# 10528   ONSHORE  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0
# 10529   ONSHORE                                          CRUDE OIL   0.0
# 10549   ONSHORE                                          CRUDE OIL   0.0
# 10722  OFFSHORE                                          CRUDE OIL   0.0
#
#        TINJ  TOTAL_COST_CURRENT     LOSS   RECOV  Value
# 10528   0.0           7358734.0  8325.00  7936.0   55.1
# 10529   0.0             40860.0     5.00     5.0   66.1
# 10549   0.0             15017.0     0.23     0.0   66.1
# 10722   0.0             14016.0     0.20     0.0   66.1

# %% [markdown]
# Changing the name from _Value_ to _TEMP_FAR_ (temperature in Farenheit)

# %%
spills_df.rename(columns={"Value": "TEMP_FAR"}, inplace=True)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\339921904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spills_df.rename(columns={"Value": "TEMP_FAR"}, inplace=True)

# %%
spills_df[spills_df['TEMP_FAR'].isnull()]
# Out:
#       IDATE      ACSTATE SIGNIFICANT SERIOUS  \
# 229    1987       Hawaii         YES      NO
# 254    1987       Hawaii         YES      NO
# 255    1986       Hawaii          NO      NO
# 256    1987       Hawaii          NO      NO
# 265    1987       Hawaii         YES      NO
# 430    1988       Hawaii         YES      NO
# 1374   1993       Hawaii         YES      NO
# 1643   1994       Hawaii          NO      NO
# 1736   1994       Hawaii         YES      NO
# 2323   1996       Hawaii         YES      NO
# 3038   2002       Hawaii          NO      NO
# 3039   2002       Hawaii         YES      NO
# 3593   2003       Hawaii          NO      NO
# 3830   2004       Hawaii         YES      NO
# 3878   2004       Hawaii          NO      NO
# 4556   2006       Hawaii          NO      NO
# 5048   2007       Hawaii         YES      NO
# 5149   2008       Hawaii          NO      NO
# 5369   2008       Hawaii         YES      NO
# 5860   2009  Puerto Rico          NO      NO
# 6224   2011  Puerto Rico         YES      NO
# 7361   2014       Hawaii          NO      NO
# 7780   2014       Hawaii         YES      NO
# 8450   2016       Hawaii          NO      NO
# 9067   2018       Hawaii         YES      NO
# 9663   2019       Hawaii          NO      NO
# 9718   2019       Hawaii          NO      NO
# 10199  2021       Hawaii          NO      NO
#
#                                             NAME OFFSHORE  \
# 229                              CHEVRON USA INC       NO
# 254                              CHEVRON USA INC       NO
# 255                              CHEVRON USA INC       NO
# 256                              CHEVRON USA INC       NO
# 265                              CHEVRON USA INC       NO
# 430                              CHEVRON USA INC       NO
# 1374    HAWIIAN INDEPENDENT REFINERY, INC (HIRI)       NO
# 1643                    CHEVRON USA INC - HAWAII       NO
# 1736              B H P PETROLEUM (AMERICAS) INC       NO
# 2323                    CHEVRON USA INC - HAWAII       NO
# 3038           AGI - AIRPORT GROUP INTERNATIONAL       NO
# 3039           AGI - AIRPORT GROUP INTERNATIONAL       NO
# 3593              HECO - HAWAII ELECTRIC COMPANY       NO
# 3830   HELCO-HAWAII ELECTRIC LIGHT COMPANY, INC.       NO
# 3878                   TESORO HAWAII CORPORATION       NO
# 4556                  TESORO HAWAII CORPORATION        NO
# 5048                   TESORO HAWAII CORPORATION       NO
# 5149                             ASIG - HONOLULU       NO
# 5369                             ASIG - HONOLULU       NO
# 5860          PIPELINES OF PUERTO RICO INCD, THE       NO
# 6224          PIPELINES OF PUERTO RICO INCD, THE  ONSHORE
# 7361           CHEVRON PRODUCTS COMPANY - HAWAII  ONSHORE
# 7780                             ASIG - HONOLULU  ONSHORE
# 8450                   HAWAII INDEPENDENT ENERGY  ONSHORE
# 9067      HECO - HAWAIIAN ELECTRIC COMPANY, INC.  ONSHORE
# 9663                    PAR HAWAII REFINING, LLC  ONSHORE
# 9718                      ISLAND ENERGY SERVICES  ONSHORE
# 10199                   PAR HAWAII REFINING, LLC  ONSHORE
#
#                                                     COMM  TFAT  TINJ  \
# 229                                             GASOLINE   0.0   0.0
# 254                                             FUEL OIL   0.0   0.0
# 255                                             FUEL OIL   0.0   0.0
# 256                                          DIESEL FUEL   0.0   0.0
# 265                                             JET FUEL   0.0   0.0
# 430                                          DIESEL FUEL   0.0   0.0
# 1374                                            JET FUEL   0.0   0.0
# 1643                                            FUEL OIL   0.0   0.0
# 1736                                            GASOLINE   0.0   0.0
# 2323                                           NOT GIVEN   0.0   0.0
# 3038                                            JET FUEL   0.0   0.0
# 3039                                        JET A-1 FUEL   0.0   0.0
# 3593                                 LOW SULFUR FUEL OIL   0.0   0.0
# 3830                              #6 FUEL OIL (BUNKER C)   0.0   0.0
# 3878                                              DIESEL   0.0   0.0
# 4556                                            TRANSMIX   0.0   0.0
# 5048                                            JET FUEL   0.0   0.0
# 5149                                            JET FUEL   0.0   0.0
# 5369                                          JET A FUEL   0.0   0.0
# 5860                      JET A COMMERCIAL AVIATION FUEL   0.0   0.0
# 6224   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 7361   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 7780   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 8450   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 9067   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 9663   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 9718   REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 10199  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
#
#        TOTAL_COST_CURRENT         LOSS       RECOV  TEMP_FAR
# 229          2.056902e+03  6000.000000    0.000000       NaN
# 254          2.056902e+03    85.000000   85.000000       NaN
# 255          4.206141e+03     1.000000    0.000000       NaN
# 256          4.113804e+03     1.000000    0.000000       NaN
# 265          0.000000e+00  2500.000000    0.000000       NaN
# 430          5.977543e+04   250.000000  200.000000       NaN
# 1374         6.249971e+04   405.000000  310.000000       NaN
# 1643         8.320546e+03     7.000000    7.000000       NaN
# 1736         3.328218e+04   100.000000   90.000000       NaN
# 2323         1.599345e+06   600.000000  600.000000       NaN
# 3038         5.920970e+04     4.761900    4.166663       NaN
# 3039         5.890651e+03    61.904700   33.333300       NaN
# 3593         2.169414e+04    10.000000   10.000000       NaN
# 3830         6.508205e+05    30.000000   24.000000       NaN
# 3878         1.004618e+04     0.595237    0.238095       NaN
# 4556         4.876202e+03     1.000000    1.000000       NaN
# 5048         1.635117e+05   310.000000   40.000000       NaN
# 5149         5.774658e+03     1.000000    0.000000       NaN
# 5369         2.607910e+05   220.000000  126.000000       NaN
# 5860         1.152662e+04    35.000000   35.000000       NaN
# 6224         5.850940e+05    66.000000   40.000000       NaN
# 7361         4.776073e+04     3.000000    3.000000       NaN
# 7780         3.177053e+06  1300.000000  820.000000       NaN
# 8450         1.325387e+03    14.000000   12.000000       NaN
# 9067         4.889733e+05    74.000000   74.000000       NaN
# 9663         9.220780e+04     0.100000    0.100000       NaN
# 9718         2.090135e+04     1.000000    1.000000       NaN
# 10199        2.742000e+04    12.000000   12.000000       NaN

# %%
spills_df['TEMP_FAR'].isnull().sum()
# Out:
# 28

# %% [markdown]
# We observe that in Hawaii and Puerto Rico there are 28 entries with no information about the temperature, so we can discard those entries without losing too much of the information.

# %%
spills_df = spills_df[spills_df['TEMP_FAR'].notna()]

# %%
spills_df
# Out:
#       IDATE     ACSTATE SIGNIFICANT SERIOUS                      NAME  \
# 0      1986    Colorado         YES      NO         WYCO PIPE LINE CO
# 1      1986       Texas         YES      NO      SEMINOLE PIPELINE CO
# 2      1986       Texas         YES      NO         MOBIL PIPELINE CO
# 3      1986       Texas         YES      NO         MOBIL PIPELINE CO
# 4      1986       Texas         YES      NO      SHELL PIPE LINE CORP
# ...     ...         ...         ...     ...                       ...
# 10527  2021  California          NO      NO    PARAMOUNT PIPELINE LLC
# 10528  2021  New Jersey         YES      NO       COLLINS PIPELINE CO
# 10529  2021       Texas          NO      NO  MID - VALLEY PIPELINE CO
# 10549  2021       Texas          NO      NO           TORRENT OIL LLC
# 10722  2021       Texas          NO      NO           TORRENT OIL LLC
#
#        OFFSHORE                                               COMM  TFAT  \
# 0            NO                                           GASOLINE   0.0
# 1            NO                                 NATURAL GAS LIQUID   0.0
# 2            NO                                          CRUDE OIL   0.0
# 3            NO                                           GASOLINE   0.0
# 4            NO                                          CRUDE OIL   0.0
# ...         ...                                                ...   ...
# 10527   ONSHORE  BIOFUEL / ALTERNATIVE FUEL(INCLUDING ETHANOL B...   0.0
# 10528   ONSHORE  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0
# 10529   ONSHORE                                          CRUDE OIL   0.0
# 10549   ONSHORE                                          CRUDE OIL   0.0
# 10722  OFFSHORE                                          CRUDE OIL   0.0
#
#        TINJ  TOTAL_COST_CURRENT     LOSS   RECOV  TEMP_FAR
# 0       0.0        1.198750e+05  1175.00     4.0      46.3
# 1       0.0        3.154606e+03    50.00     0.0      65.5
# 2       0.0        0.000000e+00   400.00   350.0      65.5
# 3       0.0        0.000000e+00   164.00    87.0      65.5
# 4       0.0        0.000000e+00   200.00   150.0      65.5
# ...     ...                 ...      ...     ...       ...
# 10527   0.0        4.000000e+04     1.00     1.0      60.4
# 10528   0.0        7.358734e+06  8325.00  7936.0      55.1
# 10529   0.0        4.086000e+04     5.00     5.0      66.1
# 10549   0.0        1.501700e+04     0.23     0.0      66.1
# 10722   0.0        1.401600e+04     0.20     0.0      66.1
#
# [10504 rows x 13 columns]

# %%
#spills_df.to_csv("C:/Users/mobis/Desktop/lab3/Python analysis for plots/spill.csv",
#    index=False)

# %% [markdown]
# ## Step 2: Merge this data with Storm Events data

# %% [markdown]
# Data accessed through **NOAA** website.

# %% [markdown]
# *Top 7 storms* that I will include in the dataset are:<br>
# - thunderstorms<br>
# - coastal flood<br>
# - lakeshore flood<br>
# - flood<br>
# - ice storm<br>
# - winter storm<br>
# - tornadoes<br>

# %%
path_storms = "C:/Users/mobis/Desktop/lab4/python/storm events/*.csv"

# %% [markdown]
# Looping through the folder containing all of the *.csv* files of storm events, end result: dataframe of all storm events with "STATE", "YEAR", and damage columns.

# %%
read_columns = ["STATE","EVENT_TYPE","YEAR","DAMAGE_PROPERTY"]
storm_df = []
for file in glob.glob(path_storms):
    sdf = pd.read_csv(file, usecols=read_columns)
    storm_df.append(sdf)

storm_table = pd.concat(storm_df)

# %%
storm_table
# Out:
#               STATE  YEAR         EVENT_TYPE DAMAGE_PROPERTY
# 0          OKLAHOMA  1950            Tornado            250K
# 1             TEXAS  1950            Tornado             25K
# 2      PENNSYLVANIA  1950            Tornado             25K
# 3      PENNSYLVANIA  1950            Tornado            2.5K
# 4      PENNSYLVANIA  1950            Tornado            2.5K
# ...             ...   ...                ...             ...
# 48077        KANSAS  2022               Hail             NaN
# 48078        KANSAS  2022              Flood           0.00K
# 48079        KANSAS  2022  Thunderstorm Wind           0.00K
# 48080        KANSAS  2022  Thunderstorm Wind           0.00K
# 48081        KANSAS  2022  Thunderstorm Wind           0.00K
#
# [1773096 rows x 4 columns]

# %% [markdown]
# Let's look closely at this df

# %%
storm_table["STATE"].nunique()
# Out:
# 69

# %%
storm_table["STATE"].unique()
# Out:
# array(['OKLAHOMA', 'TEXAS', 'PENNSYLVANIA', 'NEBRASKA', 'MISSISSIPPI',
#        'NEW MEXICO', 'ARKANSAS', 'MISSOURI', 'CONNECTICUT', 'FLORIDA',
#        'NORTH CAROLINA', 'ALABAMA', 'KENTUCKY', 'MARYLAND', 'MINNESOTA',
#        'SOUTH DAKOTA', 'IOWA', 'LOUISIANA', 'OHIO', 'KANSAS',
#        'NORTH DAKOTA', 'INDIANA', 'COLORADO', 'SOUTH CAROLINA',
#        'WEST VIRGINIA', 'WYOMING', 'GEORGIA', 'WISCONSIN', 'ILLINOIS',
#        'TENNESSEE', 'NEW JERSEY', 'MICHIGAN', 'CALIFORNIA',
#        'MASSACHUSETTS', 'NEW HAMPSHIRE', 'OREGON', 'VIRGINIA', 'ARIZONA',
#        'NEW YORK', 'MONTANA', 'MAINE', 'VERMONT', 'UTAH', 'DELAWARE',
#        'IDAHO', 'WASHINGTON', 'HAWAII', 'RHODE ISLAND', 'NEVADA',
#        'PUERTO RICO', 'Kentucky', 'DISTRICT OF COLUMBIA', 'ALASKA',
#        'VIRGIN ISLANDS', 'GUAM', 'AMERICAN SAMOA', 'ATLANTIC SOUTH',
#        'LAKE ERIE', 'LAKE HURON', 'GULF OF MEXICO', 'LAKE ST CLAIR',
#        'E PACIFIC', 'HAWAII WATERS', 'LAKE MICHIGAN', 'ATLANTIC NORTH',
#        'LAKE ONTARIO', 'ST LAWRENCE R', 'LAKE SUPERIOR', 'GULF OF ALASKA',
#        nan], dtype=object)

# %% [markdown]
# Here we see that there are 69 unique attributes for *STATE* column, which obviously is wrong. After analyzing the unique attributes individually, we see that the dataset contained incorrect entries for State. Thus, let's remove those entries.

# %%
storm_table = storm_table[(storm_table["STATE"] != "GULF OF ALASKA") & 
                          (storm_table["STATE"] != "LAKE SUPERIOR") &
                          (storm_table["STATE"] != "ST LAWRENCE R") &
                          (storm_table["STATE"] != "LAKE ONTARIO") &
                          (storm_table["STATE"] != "ATLANTIC NORTH") & 
                          (storm_table["STATE"] != "LAKE MICHIGAN") &
                          (storm_table["STATE"] != "HAWAII WATERS") &
                          (storm_table["STATE"] != "E PACIFIC") &
                          (storm_table["STATE"] != "LAKE ST CLAIR") & 
                          (storm_table["STATE"] != "GULF OF MEXICO") &
                          (storm_table["STATE"] != "LAKE HURON") &
                          (storm_table["STATE"] != "LAKE ERIE") &
                          (storm_table["STATE"] != "ATLANTIC SOUTH")
                         ]

# %% [markdown]
# Now I'll check the NA values

# %%
storm_table.isna().sum()
# Out:
# STATE                   1
# YEAR                    0
# EVENT_TYPE              0
# DAMAGE_PROPERTY    543507
# dtype: int64

# %% [markdown]
# We see huge amount of NA values in the Damage column, and since it's roughly 30% of the data, I think we can drop the NA columns (effect would be the same if we assign 0 to each data item, since I will be summing up all the damage by each state).

# %%
storm_table = storm_table.dropna()

# %%
storm_table
# Out:
#                STATE  YEAR         EVENT_TYPE DAMAGE_PROPERTY
# 0           OKLAHOMA  1950            Tornado            250K
# 1              TEXAS  1950            Tornado             25K
# 2       PENNSYLVANIA  1950            Tornado             25K
# 3       PENNSYLVANIA  1950            Tornado            2.5K
# 4       PENNSYLVANIA  1950            Tornado            2.5K
# ...              ...   ...                ...             ...
# 48070  WEST VIRGINIA  2022               Hail           0.00K
# 48078         KANSAS  2022              Flood           0.00K
# 48079         KANSAS  2022  Thunderstorm Wind           0.00K
# 48080         KANSAS  2022  Thunderstorm Wind           0.00K
# 48081         KANSAS  2022  Thunderstorm Wind           0.00K
#
# [1187786 rows x 4 columns]

# %%
storm_table["EVENT_TYPE"].unique()
# Out:
# array(['Tornado', 'Hail', 'Thunderstorm Wind',
#        'TORNADOES, TSTM WIND, HAIL', 'THUNDERSTORM WINDS/FLOODING',
#        'HAIL/ICY ROADS', 'HAIL FLOODING',
#        'THUNDERSTORM WINDS/FLASH FLOOD', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WIND/ TREES', 'THUNDERSTORM WIND/ TREE',
#        'THUNDERSTORM WINDS FUNNEL CLOU', 'TORNADO/WATERSPOUT',
#        'THUNDERSTORM WINDS/HEAVY RAIN', 'THUNDERSTORM WINDS HEAVY RAIN',
#        'THUNDERSTORM WINDS/ FLOOD', 'Winter Storm', 'Cold/Wind Chill',
#        'Heavy Snow', 'Flood', 'High Wind', 'Flash Flood', 'Blizzard',
#        'Ice Storm', 'Lightning', 'Frost/Freeze', 'Heavy Rain',
#        'Strong Wind', 'Coastal Flood', 'Wildfire', 'High Surf',
#        'Funnel Cloud', 'Winter Weather', 'Waterspout', 'Drought',
#        'Avalanche', 'Debris Flow', 'Heat', 'Tropical Storm', 'Dust Devil',
#        'Dense Fog', 'Hurricane (Typhoon)', 'Storm Surge/Tide',
#        'Marine High Wind', 'Dust Storm', 'Lake-Effect Snow',
#        'Rip Current', 'Seiche', 'Extreme Cold/Wind Chill',
#        'Excessive Heat', 'Volcanic Ash', 'Tsunami', 'Sleet',
#        'Freezing Fog', 'Lakeshore Flood', 'Astronomical Low Tide',
#        'Tropical Depression', 'Dense Smoke', 'Volcanic Ashfall',
#        'Sneakerwave', 'Hurricane'], dtype=object)

# %% [markdown]
# Now let's trim the data to show only the top 7 event types that was in our area of initial interest

# %%
storm_table = storm_table[storm_table['EVENT_TYPE'].str.contains("Thunder|THUNDER|Coast|Flood|FLOOD|Ice|Winter Storm|Tornad|TORNADO")==True]

# %%
storm_table
# Out:
#               STATE  YEAR         EVENT_TYPE DAMAGE_PROPERTY
# 0          OKLAHOMA  1950            Tornado            250K
# 1             TEXAS  1950            Tornado             25K
# 2      PENNSYLVANIA  1950            Tornado             25K
# 3      PENNSYLVANIA  1950            Tornado            2.5K
# 4      PENNSYLVANIA  1950            Tornado            2.5K
# ...             ...   ...                ...             ...
# 48066          OHIO  2022  Thunderstorm Wind           1.00K
# 48078        KANSAS  2022              Flood           0.00K
# 48079        KANSAS  2022  Thunderstorm Wind           0.00K
# 48080        KANSAS  2022  Thunderstorm Wind           0.00K
# 48081        KANSAS  2022  Thunderstorm Wind           0.00K
#
# [631019 rows x 4 columns]

# %% [markdown]
# Now we can group these storm events into 7 categories

# %%
storm_table["EVENT_TYPE"].unique()
# Out:
# array(['Tornado', 'Thunderstorm Wind', 'TORNADOES, TSTM WIND, HAIL',
#        'THUNDERSTORM WINDS/FLOODING', 'HAIL FLOODING',
#        'THUNDERSTORM WINDS/FLASH FLOOD', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WIND/ TREES', 'THUNDERSTORM WIND/ TREE',
#        'THUNDERSTORM WINDS FUNNEL CLOU', 'TORNADO/WATERSPOUT',
#        'THUNDERSTORM WINDS/HEAVY RAIN', 'THUNDERSTORM WINDS HEAVY RAIN',
#        'THUNDERSTORM WINDS/ FLOOD', 'Winter Storm', 'Flood',
#        'Flash Flood', 'Ice Storm', 'Coastal Flood', 'Lakeshore Flood'],
#       dtype=object)

# %%
storm_table["EVENT_TYPE"] = storm_table["EVENT_TYPE"].replace({"TORNADO/WATERSPOUT": "Tornado", 
                   "TORNADOES, TSTM WIND, HAIL": "Tornado",
                   "Thunderstorm Wind": "Thunderstorm",
                   "THUNDERSTORM WINDS/FLOODING": "Thunderstorm",
                   "THUNDERSTORM WINDS/FLASH FLOOD": "Thunderstorm",
                   "THUNDERSTORM WIND/ TREES": "Thunderstorm",
                   "THUNDERSTORM WINDS FUNNEL CLOU": "Thunderstorm",
                   "THUNDERSTORM WINDS/HEAVY RAIN": "Thunderstorm",
                   "THUNDERSTORM WINDS/ FLOOD": "Thunderstorm",
                   "THUNDERSTORM WINDS LIGHTNING": "Thunderstorm",
                   "THUNDERSTORM WIND/ TREE": "Thunderstorm",
                   "THUNDERSTORM WINDS HEAVY RAIN": "Thunderstorm",
                   "Flash Flood": "Flood"})
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\2643652526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   storm_table["EVENT_TYPE"] = storm_table["EVENT_TYPE"].replace({"TORNADO/WATERSPOUT": "Tornado",

# %%
storm_table
# Out:
#               STATE  YEAR    EVENT_TYPE DAMAGE_PROPERTY
# 0          OKLAHOMA  1950       Tornado            250K
# 1             TEXAS  1950       Tornado             25K
# 2      PENNSYLVANIA  1950       Tornado             25K
# 3      PENNSYLVANIA  1950       Tornado            2.5K
# 4      PENNSYLVANIA  1950       Tornado            2.5K
# ...             ...   ...           ...             ...
# 48066          OHIO  2022  Thunderstorm           1.00K
# 48078        KANSAS  2022         Flood           0.00K
# 48079        KANSAS  2022  Thunderstorm           0.00K
# 48080        KANSAS  2022  Thunderstorm           0.00K
# 48081        KANSAS  2022  Thunderstorm           0.00K
#
# [631019 rows x 4 columns]

# %% [markdown]
# Now let's change the "DAMAGE_PROPERTY" column from string to numerical values.

# %%
storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].str[:-1]
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\2175308100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].str[:-1]

# %%
storm_table[storm_table['DAMAGE_PROPERTY'] == ''].index
# Out:
# Int64Index([    2,     4,     9,    16,    18,    23,    24,    27,    28,
#                29,
#             ...
#             47917, 47930, 47931, 47932, 47969, 48047, 48068, 48276, 48341,
#             48342],
#            dtype='int64', length=108941)

# %% [markdown]
# And remove empty strings from the column during the process.

# %%
filter = storm_table["DAMAGE_PROPERTY"] != ""
storm_table = storm_table[filter]

# %%
storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].astype(float)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\3839821589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].astype(float)

# %%
storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].apply(lambda x: x*1000)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\3798005996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].apply(lambda x: x*1000)

# %%
storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].astype(int)
# Out:
# C:\Users\mobis\AppData\Local\Temp\ipykernel_16208\638450641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   storm_table['DAMAGE_PROPERTY'] = storm_table['DAMAGE_PROPERTY'].astype(int)

# %%
storm_table
# Out:
#               STATE  YEAR    EVENT_TYPE  DAMAGE_PROPERTY
# 0          OKLAHOMA  1950       Tornado           250000
# 1             TEXAS  1950       Tornado            25000
# 2      PENNSYLVANIA  1950       Tornado            25000
# 3      PENNSYLVANIA  1950       Tornado             2500
# 4      PENNSYLVANIA  1950       Tornado             2500
# ...             ...   ...           ...              ...
# 48066          OHIO  2022  Thunderstorm             1000
# 48078        KANSAS  2022         Flood                0
# 48079        KANSAS  2022  Thunderstorm                0
# 48080        KANSAS  2022  Thunderstorm                0
# 48081        KANSAS  2022  Thunderstorm                0
#
# [522078 rows x 4 columns]

# %% [markdown]
# Now it's time to group every EVENT_TYPE together (sum up).

# %%
sum_df = storm_table.groupby(['STATE','YEAR','EVENT_TYPE'],
                            as_index=False).agg({'DAMAGE_PROPERTY': 'sum'})

# %%
sum_df
# Out:
#         STATE  YEAR    EVENT_TYPE  DAMAGE_PROPERTY
# 0     ALABAMA  1950       Tornado            27500
# 1     ALABAMA  1951       Tornado            35000
# 2     ALABAMA  1952       Tornado           457500
# 3     ALABAMA  1953       Tornado           572500
# 4     ALABAMA  1954       Tornado           607530
# ...       ...   ...           ...              ...
# 7728  WYOMING  2021       Tornado                0
# 7729  WYOMING  2021  Winter Storm                0
# 7730  WYOMING  2022         Flood            30000
# 7731  WYOMING  2022  Thunderstorm             7000
# 7732  WYOMING  2022  Winter Storm                0
#
# [7733 rows x 4 columns]

# %% [markdown]
# #### Finally we can merge the oil data with our new storm events dataset!

# %% [markdown]
# For that, let's first create a new column for all of the top 7 storm events in our oil dataset.

# %% [markdown]
# First, I'll change all State column values to uppercase (to match with the other df).

# %%
spills_df['ACSTATE'] = spills_df['ACSTATE'].str.upper()

# %%
sum_df["EVENT_TYPE"].unique()
# Out:
# array(['Tornado', 'Thunderstorm', 'Flood', 'Winter Storm', 'Ice Storm',
#        'Coastal Flood', 'Lakeshore Flood'], dtype=object)

# %%
sum_df
# Out:
#         STATE  YEAR    EVENT_TYPE  DAMAGE_PROPERTY
# 0     ALABAMA  1950       Tornado            27500
# 1     ALABAMA  1951       Tornado            35000
# 2     ALABAMA  1952       Tornado           457500
# 3     ALABAMA  1953       Tornado           572500
# 4     ALABAMA  1954       Tornado           607530
# ...       ...   ...           ...              ...
# 7728  WYOMING  2021       Tornado                0
# 7729  WYOMING  2021  Winter Storm                0
# 7730  WYOMING  2022         Flood            30000
# 7731  WYOMING  2022  Thunderstorm             7000
# 7732  WYOMING  2022  Winter Storm                0
#
# [7733 rows x 4 columns]

# %%
sum_df["EVENT_TYPE"].unique()
# Out:
# array(['Tornado', 'Thunderstorm', 'Flood', 'Winter Storm', 'Ice Storm',
#        'Coastal Flood', 'Lakeshore Flood'], dtype=object)

# %%
sum_df['YEAR'] = sum_df['YEAR'].astype(str)

# %%
spills_df
# Out:
#       IDATE     ACSTATE SIGNIFICANT SERIOUS                      NAME  \
# 0      1986    COLORADO         YES      NO         WYCO PIPE LINE CO
# 1      1986       TEXAS         YES      NO      SEMINOLE PIPELINE CO
# 2      1986       TEXAS         YES      NO         MOBIL PIPELINE CO
# 3      1986       TEXAS         YES      NO         MOBIL PIPELINE CO
# 4      1986       TEXAS         YES      NO      SHELL PIPE LINE CORP
# ...     ...         ...         ...     ...                       ...
# 10527  2021  CALIFORNIA          NO      NO    PARAMOUNT PIPELINE LLC
# 10528  2021  NEW JERSEY         YES      NO       COLLINS PIPELINE CO
# 10529  2021       TEXAS          NO      NO  MID - VALLEY PIPELINE CO
# 10549  2021       TEXAS          NO      NO           TORRENT OIL LLC
# 10722  2021       TEXAS          NO      NO           TORRENT OIL LLC
#
#        OFFSHORE                                               COMM  TFAT  \
# 0            NO                                           GASOLINE   0.0
# 1            NO                                 NATURAL GAS LIQUID   0.0
# 2            NO                                          CRUDE OIL   0.0
# 3            NO                                           GASOLINE   0.0
# 4            NO                                          CRUDE OIL   0.0
# ...         ...                                                ...   ...
# 10527   ONSHORE  BIOFUEL / ALTERNATIVE FUEL(INCLUDING ETHANOL B...   0.0
# 10528   ONSHORE  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0
# 10529   ONSHORE                                          CRUDE OIL   0.0
# 10549   ONSHORE                                          CRUDE OIL   0.0
# 10722  OFFSHORE                                          CRUDE OIL   0.0
#
#        TINJ  TOTAL_COST_CURRENT     LOSS   RECOV  TEMP_FAR
# 0       0.0        1.198750e+05  1175.00     4.0      46.3
# 1       0.0        3.154606e+03    50.00     0.0      65.5
# 2       0.0        0.000000e+00   400.00   350.0      65.5
# 3       0.0        0.000000e+00   164.00    87.0      65.5
# 4       0.0        0.000000e+00   200.00   150.0      65.5
# ...     ...                 ...      ...     ...       ...
# 10527   0.0        4.000000e+04     1.00     1.0      60.4
# 10528   0.0        7.358734e+06  8325.00  7936.0      55.1
# 10529   0.0        4.086000e+04     5.00     5.0      66.1
# 10549   0.0        1.501700e+04     0.23     0.0      66.1
# 10722   0.0        1.401600e+04     0.20     0.0      66.1
#
# [10504 rows x 13 columns]

# %%
spills_df.rename(columns={"IDATE": "YEAR", 
                   "ACSTATE": "STATE"}, inplace=True)

# %% [markdown]
# Ready to merge.

# %%
cols = ['STATE', 'YEAR']

fully_merge = spills_df.merge(sum_df.pivot(index=cols, columns='EVENT_TYPE', values='DAMAGE_PROPERTY'), left_on=cols, right_index=True)

# %%
fully_merge.isna().sum()
# Out:
# YEAR                      0
# STATE                     0
# SIGNIFICANT               0
# SERIOUS                   0
# NAME                      0
# OFFSHORE                  0
# COMM                      0
# TFAT                      0
# TINJ                      0
# TOTAL_COST_CURRENT        0
# LOSS                      0
# RECOV                     0
# TEMP_FAR                  0
# Coastal Flood          7165
# Flood                  2038
# Ice Storm              5704
# Lakeshore Flood       10422
# Thunderstorm           1399
# Tornado                 231
# Winter Storm           3588
# dtype: int64

# %% [markdown]
# Here we observe that Lakeshore Flood happens very rarely and there is not enough data for it -> we can just remove this feature.

# %%
final_df = fully_merge.drop(["Lakeshore Flood"], axis=1)

# %%
final_df.isna().sum()
# Out:
# YEAR                     0
# STATE                    0
# SIGNIFICANT              0
# SERIOUS                  0
# NAME                     0
# OFFSHORE                 0
# COMM                     0
# TFAT                     0
# TINJ                     0
# TOTAL_COST_CURRENT       0
# LOSS                     0
# RECOV                    0
# TEMP_FAR                 0
# Coastal Flood         7165
# Flood                 2038
# Ice Storm             5704
# Thunderstorm          1399
# Tornado                231
# Winter Storm          3588
# dtype: int64

# %% [markdown]
# Now let's drop all the data items containing NA values so we fit this to our analysis.

# %%
final_df = final_df.dropna()

# %%
final_df
# Out:
#        YEAR         STATE SIGNIFICANT SERIOUS  \
# 2041   1996         TEXAS         YES      NO
# 2050   1996         TEXAS         YES      NO
# 2054   1996         TEXAS         YES      NO
# 2061   1996         TEXAS         YES      NO
# 2062   1996         TEXAS         YES      NO
# ...     ...           ...         ...     ...
# 10357  2021  PENNSYLVANIA          NO      NO
# 10374  2021  PENNSYLVANIA          NO      NO
# 10379  2021  PENNSYLVANIA         YES      NO
# 10415  2021  PENNSYLVANIA          NO      NO
# 10455  2021  PENNSYLVANIA         YES      NO
#
#                                                     NAME OFFSHORE  \
# 2041   ENRON LIQUIDS PIPELINE CO (HYDROCARBON TRANS INC)       NO
# 2050                   TEXAS EASTERN PRODUCT PIPELINE CO       NO
# 2054                              WESTTEX 66 PIPELINE CO       NO
# 2061                              WESTTEX 66 PIPELINE CO       NO
# 2062                                 CHEVRON PIPELINE CO       NO
# ...                                                  ...      ...
# 10357                               BUCKEYE PARTNERS, LP  ONSHORE
# 10374                               BUCKEYE PARTNERS, LP  ONSHORE
# 10379                             KIANTONE PIPELINE CORP  ONSHORE
# 10415                               BUCKEYE PARTNERS, LP  ONSHORE
# 10455                               BUCKEYE PARTNERS, LP  ONSHORE
#
#                                                     COMM  TFAT  TINJ  \
# 2041                                      CARBON DIOXIDE   0.0   0.0
# 2050                                            FUEL OIL   0.0   0.0
# 2054                                  NATURAL GAS LIQUID   0.0   0.0
# 2061                                  NATURAL GAS LIQUID   0.0   0.0
# 2062                                           CRUDE OIL   0.0   0.0
# ...                                                  ...   ...   ...
# 10357  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 10374  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 10379                                          CRUDE OIL   0.0   0.0
# 10415  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
# 10455  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0   0.0
#
#        TOTAL_COST_CURRENT     LOSS    RECOV  TEMP_FAR  Coastal Flood  \
# 2041         0.000000e+00    95.00     0.00      65.4         1700.0
# 2050         9.596067e+03   190.00   187.00      65.4         1700.0
# 2054         1.599345e+03    15.00     0.00      65.4         1700.0
# 2061         1.599345e+03    15.00     0.00      65.4         1700.0
# 2062         1.921772e+04   370.00   340.00      65.4         1700.0
# ...                   ...      ...      ...       ...            ...
# 10357        1.553400e+04     0.25     0.25      51.2            0.0
# 10374        1.581600e+04     0.20     0.20      51.2            0.0
# 10379        1.194678e+06  2672.00  2672.00      51.2            0.0
# 10415        4.075000e+03     9.00     9.00      51.2            0.0
# 10455        1.552000e+05     1.00     1.00      51.2            0.0
#
#            Flood  Ice Storm  Thunderstorm    Tornado  Winter Storm
# 2041   1580950.0    30000.0     5691960.0   655870.0        1500.0
# 2050   1580950.0    30000.0     5691960.0   655870.0        1500.0
# 2054   1580950.0    30000.0     5691960.0   655870.0        1500.0
# 2061   1580950.0    30000.0     5691960.0   655870.0        1500.0
# 2062   1580950.0    30000.0     5691960.0   655870.0        1500.0
# ...          ...        ...           ...        ...           ...
# 10357  3035000.0        0.0    25791950.0  2087500.0           0.0
# 10374  3035000.0        0.0    25791950.0  2087500.0           0.0
# 10379  3035000.0        0.0    25791950.0  2087500.0           0.0
# 10415  3035000.0        0.0    25791950.0  2087500.0           0.0
# 10455  3035000.0        0.0    25791950.0  2087500.0           0.0
#
# [2181 rows x 19 columns]

# %% [markdown]
# Here we observe 2181 rows, which is pretty good number to do our analysis with. Here is our final dataframe, now I will proceed to the analysis for the plots in another Jupyter file!

# %%
#final_df.to_csv("C:/Users/mobis/Desktop/lab4/python/oil_spill.csv",index=False)

# %% [markdown]
# Let's remove the categorical variables (except for States) and drop duplicates.

# %%
final_df = final_df.drop(columns=["SIGNIFICANT","SERIOUS","NAME","OFFSHORE","COMM"],axis=1)

# %%
final_df = final_df.drop_duplicates()

# %%
#final_df.to_csv("C:/Users/mobis/Desktop/lab4 correct/numeric_oil_spill.csv",index=False)

# %% [markdown]
# For my visualizations for now I decided to group everything by Year and drop the State column.

# %%
final_df
# Out:
#        YEAR         STATE  TFAT  TINJ  TOTAL_COST_CURRENT     LOSS    RECOV  \
# 2041   1996         TEXAS   0.0   0.0        0.000000e+00    95.00     0.00
# 2050   1996         TEXAS   0.0   0.0        9.596067e+03   190.00   187.00
# 2054   1996         TEXAS   0.0   0.0        1.599345e+03    15.00     0.00
# 2062   1996         TEXAS   0.0   0.0        1.921772e+04   370.00   340.00
# 2064   1996         TEXAS   0.0   0.0        1.119541e+04   233.00   230.00
# ...     ...           ...   ...   ...                 ...      ...      ...
# 10357  2021  PENNSYLVANIA   0.0   0.0        1.553400e+04     0.25     0.25
# 10374  2021  PENNSYLVANIA   0.0   0.0        1.581600e+04     0.20     0.20
# 10379  2021  PENNSYLVANIA   0.0   0.0        1.194678e+06  2672.00  2672.00
# 10415  2021  PENNSYLVANIA   0.0   0.0        4.075000e+03     9.00     9.00
# 10455  2021  PENNSYLVANIA   0.0   0.0        1.552000e+05     1.00     1.00
#
#        TEMP_FAR  Coastal Flood      Flood  Ice Storm  Thunderstorm    Tornado  \
# 2041       65.4         1700.0  1580950.0    30000.0     5691960.0   655870.0
# 2050       65.4         1700.0  1580950.0    30000.0     5691960.0   655870.0
# 2054       65.4         1700.0  1580950.0    30000.0     5691960.0   655870.0
# 2062       65.4         1700.0  1580950.0    30000.0     5691960.0   655870.0
# 2064       65.4         1700.0  1580950.0    30000.0     5691960.0   655870.0
# ...         ...            ...        ...        ...           ...        ...
# 10357      51.2            0.0  3035000.0        0.0    25791950.0  2087500.0
# 10374      51.2            0.0  3035000.0        0.0    25791950.0  2087500.0
# 10379      51.2            0.0  3035000.0        0.0    25791950.0  2087500.0
# 10415      51.2            0.0  3035000.0        0.0    25791950.0  2087500.0
# 10455      51.2            0.0  3035000.0        0.0    25791950.0  2087500.0
#
#        Winter Storm
# 2041         1500.0
# 2050         1500.0
# 2054         1500.0
# 2062         1500.0
# 2064         1500.0
# ...             ...
# 10357           0.0
# 10374           0.0
# 10379           0.0
# 10415           0.0
# 10455           0.0
#
# [2171 rows x 14 columns]

# %% [markdown]
# Ended up removing temp + extreme storm data for final visualization, now have 10,000+ rows, makes more sense to analyze these for their geographical location

# %%
df2 = pd.read_csv("C:/Users/mobis/Desktop/lab4/python/spill.csv")

# %%
df2
# Out:
#        IDATE     ACSTATE SIGNIFICANT SERIOUS                      NAME  \
# 0       1986    Colorado         YES      NO         WYCO PIPE LINE CO
# 1       1986       Texas         YES      NO      SEMINOLE PIPELINE CO
# 2       1986       Texas         YES      NO         MOBIL PIPELINE CO
# 3       1986       Texas         YES      NO         MOBIL PIPELINE CO
# 4       1986       Texas         YES      NO      SHELL PIPE LINE CORP
# ...      ...         ...         ...     ...                       ...
# 10499   2021  California          NO      NO    PARAMOUNT PIPELINE LLC
# 10500   2021  New Jersey         YES      NO       COLLINS PIPELINE CO
# 10501   2021       Texas          NO      NO  MID - VALLEY PIPELINE CO
# 10502   2021       Texas          NO      NO           TORRENT OIL LLC
# 10503   2021       Texas          NO      NO           TORRENT OIL LLC
#
#        OFFSHORE                                               COMM  TFAT  \
# 0            NO                                           GASOLINE   0.0
# 1            NO                                 NATURAL GAS LIQUID   0.0
# 2            NO                                          CRUDE OIL   0.0
# 3            NO                                           GASOLINE   0.0
# 4            NO                                          CRUDE OIL   0.0
# ...         ...                                                ...   ...
# 10499   ONSHORE  BIOFUEL / ALTERNATIVE FUEL(INCLUDING ETHANOL B...   0.0
# 10500   ONSHORE  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...   0.0
# 10501   ONSHORE                                          CRUDE OIL   0.0
# 10502   ONSHORE                                          CRUDE OIL   0.0
# 10503  OFFSHORE                                          CRUDE OIL   0.0
#
#        TINJ  TOTAL_COST_CURRENT     LOSS   RECOV  TEMP_FAR
# 0       0.0        1.198750e+05  1175.00     4.0      46.3
# 1       0.0        3.154606e+03    50.00     0.0      65.5
# 2       0.0        0.000000e+00   400.00   350.0      65.5
# 3       0.0        0.000000e+00   164.00    87.0      65.5
# 4       0.0        0.000000e+00   200.00   150.0      65.5
# ...     ...                 ...      ...     ...       ...
# 10499   0.0        4.000000e+04     1.00     1.0      60.4
# 10500   0.0        7.358734e+06  8325.00  7936.0      55.1
# 10501   0.0        4.086000e+04     5.00     5.0      66.1
# 10502   0.0        1.501700e+04     0.23     0.0      66.1
# 10503   0.0        1.401600e+04     0.20     0.0      66.1
#
# [10504 rows x 13 columns]

# %%
df2 = df2.drop(["SIGNIFICANT","SERIOUS","NAME","OFFSHORE","COMM"],axis=1)

# %%
temp = df2[["TEMP_FAR","IDATE"]]

# %%
df2 = df2.drop(["TEMP_FAR"],axis=1)

# %%
df2 = df2.drop(["ACSTATE"],axis=1)

# %%
df2
# Out:
#        IDATE  TFAT  TINJ  TOTAL_COST_CURRENT     LOSS   RECOV
# 0       1986   0.0   0.0        1.198750e+05  1175.00     4.0
# 1       1986   0.0   0.0        3.154606e+03    50.00     0.0
# 2       1986   0.0   0.0        0.000000e+00   400.00   350.0
# 3       1986   0.0   0.0        0.000000e+00   164.00    87.0
# 4       1986   0.0   0.0        0.000000e+00   200.00   150.0
# ...      ...   ...   ...                 ...      ...     ...
# 10499   2021   0.0   0.0        4.000000e+04     1.00     1.0
# 10500   2021   0.0   0.0        7.358734e+06  8325.00  7936.0
# 10501   2021   0.0   0.0        4.086000e+04     5.00     5.0
# 10502   2021   0.0   0.0        1.501700e+04     0.23     0.0
# 10503   2021   0.0   0.0        1.401600e+04     0.20     0.0
#
# [10504 rows x 6 columns]

# %%
df2.rename(columns={"IDATE": "YEAR"}, inplace=True)

# %%
df2.loc[df2['YEAR'] == 1986, 'RECOV'].sum()
# Out:
# 62474.0

# %%
df5 = df2.groupby(by="YEAR",as_index=False).sum()

# %%
df5
# Out:
#     YEAR  TFAT    TINJ  TOTAL_COST_CURRENT           LOSS          RECOV
# 0   1986   3.0     5.0        2.824560e+07  138241.000000   62474.000000
# 1   1987   3.0    19.0        2.698374e+07  387268.000000   82975.000000
# 2   1988   2.0    16.0        6.370637e+07  198147.000000   82611.000000
# 3   1989   3.0    38.0        1.687785e+07  201758.000000   80579.000000
# 4   1990   3.0     7.0        2.903139e+07  124275.000000   69612.000000
# 5   1991   0.0     9.0        6.740544e+07  200567.000000  144793.000000
# 6   1992   5.0    38.0        6.306914e+07  134995.000000   67100.000000
# 7   1993   0.0    10.0        4.736132e+07  116345.000000   58933.000000
# 8   1994   1.0  1858.0        1.034095e+08  164280.000000   50288.000000
# 9   1995   3.0    11.0        5.298538e+07  110237.000000   57124.000000
# 10  1996   5.0    13.0        1.339792e+08  159715.000000   58767.000000
# 11  1997   0.0     5.0        6.738783e+07  190030.000000   89792.000000
# 12  1998   2.0     5.0        8.156646e+07  139520.000000   88197.000000
# 13  1999   4.0    19.0        1.292604e+08  163836.000000   62689.000000
# 14  2000   1.0     4.0        1.967838e+08  104308.000000   51650.000000
# 15  2001   0.0    10.0        3.530580e+07   98320.000000   20892.000000
# 16  2002   1.0     0.0        7.097690e+07   96763.380868   18872.214253
# 17  2003   0.0     0.0        9.546937e+07   81284.928500   30408.404727
# 18  2004   5.0    16.0        1.148884e+08   76877.833274   18338.547585
# 19  2005   2.0     2.0        3.699947e+08  136983.047576   91825.595215
# 20  2006   0.0     2.0        6.959358e+07  137018.714239   83774.190457
# 21  2007   4.0    10.0        7.547292e+07   95279.142675   26607.547588
# 22  2008   2.0     2.0        1.697299e+08  102134.690392   32440.023763
# 23  2009   0.0     1.0        7.152002e+07   53479.094767   22395.499575
# 24  2010   1.0     3.0        1.308737e+09  174396.970000   51106.690000
# 25  2011   0.0     1.0        3.252663e+08  130867.700000   31695.360000
# 26  2012   3.0     4.0        1.703832e+08   52503.680000   16636.770000
# 27  2013   1.0     6.0        3.193382e+08  197029.550000   31869.240000
# 28  2014   0.0     0.0        1.555054e+08   55813.450000   25376.130000
# 29  2015   1.0     0.0        2.856148e+08  137586.720000   21125.650000
# 30  2016   3.0     9.0        2.339855e+08  101126.620000   39900.730000
# 31  2017   1.0     1.0        1.771547e+08  119715.400000   44692.090000
# 32  2018   0.0     2.0        1.686509e+08  162025.000000   37626.150000
# 33  2019   0.0     0.0        1.647882e+08   82056.380000   32580.640000
# 34  2020   5.0    12.0        1.874543e+08  191914.330000   50750.600000
# 35  2021   0.0     1.0        9.520132e+07   98521.960000   22453.990000

# %%
sum_df
# Out:
#         STATE  YEAR    EVENT_TYPE  DAMAGE_PROPERTY
# 0     ALABAMA  1950       Tornado            27500
# 1     ALABAMA  1951       Tornado            35000
# 2     ALABAMA  1952       Tornado           457500
# 3     ALABAMA  1953       Tornado           572500
# 4     ALABAMA  1954       Tornado           607530
# ...       ...   ...           ...              ...
# 7728  WYOMING  2021       Tornado                0
# 7729  WYOMING  2021  Winter Storm                0
# 7730  WYOMING  2022         Flood            30000
# 7731  WYOMING  2022  Thunderstorm             7000
# 7732  WYOMING  2022  Winter Storm                0
#
# [7733 rows x 4 columns]

# %%
df10 = pd.pivot_table(
    sum_df, index=["YEAR"], columns="EVENT_TYPE", values="DAMAGE_PROPERTY"
).reset_index()

# %%
df10.head(2)
# Out:
# EVENT_TYPE  YEAR  Coastal Flood  Flood  Ice Storm  Lakeshore Flood  \
# 0           1950            NaN    NaN        NaN              NaN
# 1           1951            NaN    NaN        NaN              NaN
#
# EVENT_TYPE  Thunderstorm        Tornado  Winter Storm
# 0                    NaN  566638.333333           NaN
# 1                    NaN  301742.571429           NaN

# %%
df5.head(2)
# Out:
#    YEAR  TFAT  TINJ  TOTAL_COST_CURRENT      LOSS    RECOV
# 0  1986   3.0   5.0        2.824560e+07  138241.0  62474.0
# 1  1987   3.0  19.0        2.698374e+07  387268.0  82975.0

# %%
df5['YEAR'] = df5['YEAR'].astype(str)

# %%
new_df = df5.merge(df10, left_on='YEAR', right_on='YEAR')

# %%
new_df = new_df.fillna(0)

# %%
new_df["TEMP_FAR"] = [53.32,
53.33,
52.63,
51.84,
53.51,
53.16,
52.60,
51.26,
52.87,
52.65,
51.88,
52.20,
54.23,
53.88,
53.27,
53.69,
53.21,
53.26,
53.10,
53.64,
54.25,
53.65,
52.29,
52.39,
52.98,
53.18,
55.28,
52.43,
52.54,
54.40,
54.92,
54.55,
53.52,
52.68,
54.37,
54.51,
]

# %%
new_df
# Out:
#     YEAR  TFAT    TINJ  TOTAL_COST_CURRENT           LOSS          RECOV  \
# 0   1986   3.0     5.0        2.824560e+07  138241.000000   62474.000000
# 1   1987   3.0    19.0        2.698374e+07  387268.000000   82975.000000
# 2   1988   2.0    16.0        6.370637e+07  198147.000000   82611.000000
# 3   1989   3.0    38.0        1.687785e+07  201758.000000   80579.000000
# 4   1990   3.0     7.0        2.903139e+07  124275.000000   69612.000000
# 5   1991   0.0     9.0        6.740544e+07  200567.000000  144793.000000
# 6   1992   5.0    38.0        6.306914e+07  134995.000000   67100.000000
# 7   1993   0.0    10.0        4.736132e+07  116345.000000   58933.000000
# 8   1994   1.0  1858.0        1.034095e+08  164280.000000   50288.000000
# 9   1995   3.0    11.0        5.298538e+07  110237.000000   57124.000000
# 10  1996   5.0    13.0        1.339792e+08  159715.000000   58767.000000
# 11  1997   0.0     5.0        6.738783e+07  190030.000000   89792.000000
# 12  1998   2.0     5.0        8.156646e+07  139520.000000   88197.000000
# 13  1999   4.0    19.0        1.292604e+08  163836.000000   62689.000000
# 14  2000   1.0     4.0        1.967838e+08  104308.000000   51650.000000
# 15  2001   0.0    10.0        3.530580e+07   98320.000000   20892.000000
# 16  2002   1.0     0.0        7.097690e+07   96763.380868   18872.214253
# 17  2003   0.0     0.0        9.546937e+07   81284.928500   30408.404727
# 18  2004   5.0    16.0        1.148884e+08   76877.833274   18338.547585
# 19  2005   2.0     2.0        3.699947e+08  136983.047576   91825.595215
# 20  2006   0.0     2.0        6.959358e+07  137018.714239   83774.190457
# 21  2007   4.0    10.0        7.547292e+07   95279.142675   26607.547588
# 22  2008   2.0     2.0        1.697299e+08  102134.690392   32440.023763
# 23  2009   0.0     1.0        7.152002e+07   53479.094767   22395.499575
# 24  2010   1.0     3.0        1.308737e+09  174396.970000   51106.690000
# 25  2011   0.0     1.0        3.252663e+08  130867.700000   31695.360000
# 26  2012   3.0     4.0        1.703832e+08   52503.680000   16636.770000
# 27  2013   1.0     6.0        3.193382e+08  197029.550000   31869.240000
# 28  2014   0.0     0.0        1.555054e+08   55813.450000   25376.130000
# 29  2015   1.0     0.0        2.856148e+08  137586.720000   21125.650000
# 30  2016   3.0     9.0        2.339855e+08  101126.620000   39900.730000
# 31  2017   1.0     1.0        1.771547e+08  119715.400000   44692.090000
# 32  2018   0.0     2.0        1.686509e+08  162025.000000   37626.150000
# 33  2019   0.0     0.0        1.647882e+08   82056.380000   32580.640000
# 34  2020   5.0    12.0        1.874543e+08  191914.330000   50750.600000
# 35  2021   0.0     1.0        9.520132e+07   98521.960000   22453.990000
#
#     Coastal Flood         Flood     Ice Storm  Lakeshore Flood  Thunderstorm  \
# 0        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 1        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 2        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 3        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 4        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 5        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 6        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 7        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  2.726534e+06
# 8        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  4.871943e+06
# 9        0.000000  0.000000e+00  0.000000e+00     0.000000e+00  2.384729e+06
# 10   16118.888889  4.722298e+05  8.072706e+04     0.000000e+00  9.657510e+05
# 11   40300.000000  1.204514e+06  8.019312e+04     0.000000e+00  1.671377e+06
# 12  536836.666667  2.779668e+06  7.624212e+05     0.000000e+00  3.515756e+06
# 13   30333.333333  1.488872e+06  1.079100e+05     0.000000e+00  2.375243e+06
# 14       0.000000  1.911623e+06  6.857269e+05     0.000000e+00  2.686821e+06
# 15       0.000000  1.981398e+06  4.797750e+05     0.000000e+00  2.300032e+06
# 16       0.000000  1.650634e+06  8.099961e+05     0.000000e+00  2.098683e+06
# 17       0.000000  2.859318e+06  1.090400e+06     0.000000e+00  2.504213e+06
# 18       0.000000  2.825070e+06  3.265000e+05     0.000000e+00  2.133286e+06
# 19  450000.000000  2.979869e+06  5.676263e+05     0.000000e+00  2.099707e+06
# 20  217000.000000  1.658008e+06  5.700000e+05     1.000000e+04  2.591087e+06
# 21  191775.555556  2.886013e+06  1.061082e+06     5.000000e+04  2.545682e+06
# 22   68000.000000  4.307197e+06  3.428003e+05     0.000000e+00  3.833900e+06
# 23  316568.421053  2.993928e+06  5.391190e+05     0.000000e+00  3.180671e+06
# 24   27610.000000  3.960491e+06  2.735679e+05     0.000000e+00  2.978376e+06
# 25  191583.333333  3.695729e+06  1.329243e+06     8.816667e+04  4.582685e+06
# 26  523086.363636  1.116796e+06  1.920100e+05     0.000000e+00  3.215336e+06
# 27  166550.000000  2.917782e+06  6.125100e+05     0.000000e+00  2.511880e+06
# 28   22911.764706  2.024105e+06  4.631000e+05     1.535000e+05  2.226801e+06
# 29  376190.476190  4.316901e+06  2.056645e+06     0.000000e+00  1.977797e+06
# 30   34452.380952  2.449287e+06  3.759536e+05     3.000000e+03  2.092879e+06
# 31   19781.250000  3.097517e+06  6.975467e+05     2.385000e+05  2.304853e+06
# 32  337394.444444  1.934531e+06  7.325000e+04     1.438500e+05  1.928385e+06
# 33   20227.272727  3.623669e+06  1.213716e+05     5.317000e+06  1.792094e+06
# 34   17315.789474  1.098181e+06  2.230000e+04     5.817143e+05  2.364784e+06
# 35  119666.666667  2.101199e+06  3.463889e+05     5.033333e+05  2.262167e+06
#
#          Tornado  Winter Storm  TEMP_FAR
# 0   1.131052e+06  0.000000e+00     53.32
# 1   8.516141e+05  0.000000e+00     53.33
# 2   1.226577e+06  0.000000e+00     52.63
# 3   1.026324e+06  0.000000e+00     51.84
# 4   1.580922e+06  0.000000e+00     53.51
# 5   1.353087e+06  0.000000e+00     53.16
# 6   1.602873e+06  0.000000e+00     52.60
# 7   1.569593e+06  0.000000e+00     51.26
# 8   2.044412e+06  0.000000e+00     52.87
# 9   1.361413e+06  0.000000e+00     52.65
# 10  2.858270e+05  1.912903e+05     51.88
# 11  9.574345e+05  2.982450e+05     52.20
# 12  1.867426e+06  3.316381e+05     54.23
# 13  1.715316e+06  4.492062e+05     53.88
# 14  1.124771e+06  4.920033e+05     53.27
# 15  1.577832e+06  6.199013e+05     53.69
# 16  1.075661e+06  4.898312e+05     53.21
# 17  1.553658e+06  6.316512e+05     53.26
# 18  1.783973e+06  9.610118e+05     53.10
# 19  1.627420e+06  1.424968e+06     53.64
# 20  1.664234e+06  6.111412e+05     54.25
# 21  1.501792e+06  7.577442e+05     53.65
# 22  2.759744e+06  8.661145e+05     52.29
# 23  1.587978e+06  5.615386e+05     52.39
# 24  2.053027e+06  6.125612e+05     52.98
# 25  3.029978e+06  6.528440e+05     53.18
# 26  1.230616e+06  2.110921e+05     55.28
# 27  1.504623e+06  4.007027e+05     52.43
# 28  1.191224e+06  5.470308e+05     52.54
# 29  1.205681e+06  5.866047e+05     54.40
# 30  1.173291e+06  9.972619e+04     54.92
# 31  2.474688e+06  1.344359e+05     54.55
# 32  1.255331e+06  5.555581e+05     53.52
# 33  1.765170e+06  2.132297e+05     52.68
# 34  1.542507e+06  1.006471e+05     54.37
# 35  1.663472e+06  3.715084e+05     54.51

# %% [markdown]
# So this is the final dataset!

# %%
new_df.to_csv("C:/Users/mobis/Desktop/lab4 correct/spills_events.csv",
                    index=False)

# %%
###############################################################################
